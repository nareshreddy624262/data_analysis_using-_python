# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("netflix1.csv")

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# #  how many shows are comes under movie

# %%
c = 0
for i in df["type"]:
    if i == "Movie":
        c+=1
print(c,"shows are comes under movies ")
# Out:
# 6126 shows are comes under movies

# %% [markdown]
# # how many shows are comes under TV shows

# %%
print(len(df["type"])-c,"shows are comes under TV shows")
# Out:
# 2664 shows are comes under TV shows

# %%
df["title"].unique().sum()
# Out:
# "Dick Johnson Is DeadGanglandsMidnight MassConfessions of an Invisible GirlSankofaThe Great British Baking ShowThe StarlingMotu Patlu in the Game of ZonesJe Suis KarlMotu Patlu in WonderlandMotu Patlu: Deep Sea AdventureMotu Patlu: Mission Moon99 Songs (Tamil)Bridgerton - The AfterpartyBling Empire - The AfterpartyCobra Kai - The AfterpartyThe Circle - The AfterpartyJailbirds New OrleansCrime Stories: India DetectivesTrue: Winter WishesTrue: Magical FriendsTrue: Wonderful WishesDance & Sing with TrueMy Little Pony: A New GenerationBangkok BreakingEurope's Most Dangerous Man: Otto Skorzeny in SpainSamudri LootereMonsters Inside: The 24 Faces of Billy MilliganGo! Go! Cory Carson: Chrissy Takes the WheelJeansGrown UpsDark SkiesParanoiaJaguarChicago Party AuntSquid GameTayo and Little WizardsThe World's Most Amazing Vacation RentalsMetal Shop MastersPokémon Master Journeys: The SeriesTitipo TitipoMighty RajuTobot Galaxy DetectivesHotel Del LunaBrave Animated SeriesHow to Be a CowboyOldst
# ...

# %%
for i in df["title"].unique():
    print(i)
# Out:
# Dick Johnson Is Dead
# Ganglands
# Midnight Mass
# Confessions of an Invisible Girl
# Sankofa
# The Great British Baking Show
# The Starling
# Motu Patlu in the Game of Zones
# Je Suis Karl
# Motu Patlu in Wonderland
# Motu Patlu: Deep Sea Adventure
# Motu Patlu: Mission Moon
# 99 Songs (Tamil)
# Bridgerton - The Afterparty
# Bling Empire - The Afterparty
# Cobra Kai - The Afterparty
# The Circle - The Afterparty
# Jailbirds New Orleans
# Crime Stories: India Detectives
# True: Winter Wishes
# True: Magical Friends
# True: Wonderful Wishes
# Dance & Sing with True
# My Little Pony: A New Generation
# Bangkok Breaking
# Europe's Most Dangerous Man: Otto Skorzeny in Spain
# Samudri Lootere
# Monsters Inside: The 24 Faces of Billy Milligan
# Go! Go! Cory Carson: Chrissy Takes the Wheel
# Jeans
# Grown Ups
# Dark Skies
# Paranoia
# Jaguar
# Chicago Party Aunt
# Squid Game
# Tayo and Little Wizards
# The World's Most Amazing Vacation Rentals
# Metal Shop Masters
# ...

# %%
df["director"].unique()
# Out:
# array(['Kirsten Johnson', 'Julien Leclercq', 'Mike Flanagan', ...,
#        'Majid Al Ansari', 'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
for i in df["director"].unique():
    print(i)
# Out:
# Kirsten Johnson
# Julien Leclercq
# Mike Flanagan
# Bruno Garotti
# Haile Gerima
# Andy Devonshire
# Theodore Melfi
# Suhas Kadav
# Christian Schwochow
# Not Given
# Krysia Plonka, Kristian Mercado
# Mark Thornton, Todd Kauffman
# Robert Cullen, José Luis Ucha
# Kongkiat Komesiri
# Pedro de Echave García, Pablo Azorín Williams
# Anirban Majumder
# Olivier Megaton
# Alex Woo, Stanley Moore
# S. Shankar
# Dennis Dugan
# Scott Stewart
# Robert Luketic
# Rajiv Menon
# Adam Salky
# K.S. Ravikumar
# Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket Chaudhary
# Daniel Sandu
# Cédric Jimenez
# George Nolfi
# Bunmi Ajakaiye
# Ben Simms
# Steven Spielberg
# Jeannot Szwarc
# Joe Alves
# Joseph Sargent
# Daniel Espinosa
# Antoine Fuqua
# Toshiya Shinohara
# Tyler Greco
# Masahiko Murata
# Hajime Kamegaki
# Hirotsugu Kawasaki
# Toshiyuki Tsuru
# Tensai Okamura
# Kemi Adetiba
# Cedric Nicolas-Troyan
# JJC Skillz, Funke Akindele
# Thomas Sieben
# Alice Waddington
# Mona Achache, Patricia Tourancheau
# ...

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
for i in df["title"]:
    for j in df["type"]:
        if i == j:
            print(i,"----->",j)

# %%
type = {}
for name in df["country"].unique():
    ct = 0
    for i in df["country"]:
        ct+=1
        type[name] = ct
print(type)
# Out:
# {'United States': 8790, 'France': 8790, 'Brazil': 8790, 'United Kingdom': 8790, 'India': 8790, 'Germany': 8790, 'Pakistan': 8790, 'Not Given': 8790, 'China': 8790, 'South Africa': 8790, 'Japan': 8790, 'Nigeria': 8790, 'Spain': 8790, 'Philippines': 8790, 'Australia': 8790, 'Argentina': 8790, 'Canada': 8790, 'Hong Kong': 8790, 'Italy': 8790, 'New Zealand': 8790, 'Egypt': 8790, 'Colombia': 8790, 'Mexico': 8790, 'Belgium': 8790, 'Switzerland': 8790, 'Taiwan': 8790, 'Bulgaria': 8790, 'Poland': 8790, 'South Korea': 8790, 'Saudi Arabia': 8790, 'Thailand': 8790, 'Indonesia': 8790, 'Kuwait': 8790, 'Malaysia': 8790, 'Vietnam': 8790, 'Lebanon': 8790, 'Romania': 8790, 'Syria': 8790, 'United Arab Emirates': 8790, 'Sweden': 8790, 'Mauritius': 8790, 'Austria': 8790, 'Turkey': 8790, 'Czech Republic': 8790, 'Cameroon': 8790, 'Netherlands': 8790, 'Ireland': 8790, 'Russia': 8790, 'Kenya': 8790, 'Chile': 8790, 'Uruguay': 8790, 'Bangladesh': 8790, 'Portugal': 8790, 'Hungary': 8790, 'Norway': 8790, 'Singa
# ...
