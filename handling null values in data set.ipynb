# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("TV_show_data.csv")

# %%
data
# Out:
#                             Name  \
# 0                   Breaking Bad
# 1                        Firefly
# 2     Avatar: The Last Airbender
# 3                       Sherlock
# 4                Attack on Titan
# ...                          ...
# 1528            All-Star Academy
# 1529     Neighbors with Benefits
# 1530                 Funny Girls
# 1531      Cedric's Barber Battle
# 1532              The Ambassador
#
#                                                 Summary  Average Runtime  \
# 0     Breaking Bad follows protagonist Walter White,...             60.0
# 1     Five hundred years in the future, a renegade c...             64.0
# 2     Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3     Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4     Known in Japan as Shingeki no Kyojin, many yea...             26.0
# ...                                                 ...              ...
# ...

# %%
data.head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                              Summary  Average Runtime  \
# 0  Breaking Bad follows protagonist Walter White,...             60.0
# 1  Five hundred years in the future, a renegade c...             64.0
# 2  Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3  Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4  Known in Japan as Shingeki no Kyojin, many yea...             26.0
#
#      End Date Premiere Date                                       Genres  \
# 0  2008-01-20    2019-10-11               ['Drama', 'Crime', 'Thriller']
# 1  2002-09-20    2002-12-20    ['Drama', 'Adventure', 'Science-Fiction']
# 2  2005-02-21    2008-07-19           ['Action', 'Adventure', 'Fantasy']
# ...

# %%
data["Language"].unique()
# Out:
# array(['English', 'Japanese', 'Danish', 'German', 'Spanish', 'Dutch',
#        'Korean', 'French', 'Swedish', 'Portuguese'], dtype=object)

# %%
for i in data.columns:
    print(i)
# Out:
# Name
# Summary
# Average Runtime
# End Date
# Premiere Date
# Genres
# Type
# Language
# Network
# Rating
# Schedule (days)
# Schedule (time)
# Total Seasons
# Total Episodes
# Character Names
# Person Names
# Official Site

# %%
data["Name"].unique()
# Out:
# array(['Breaking Bad', 'Firefly', 'Avatar: The Last Airbender', ...,
#        'Funny Girls', "Cedric's Barber Battle", 'The Ambassador'],
#       dtype=object)

# %%
data.shape
# Out:
# (1533, 17)

# %%
data.isnull().sum()
# Out:
# Name                 0
# Summary              0
# Average Runtime      1
# End Date             1
# Premiere Date      156
# Genres               0
# Type                 0
# Language             0
# Network             69
# Rating             278
# Schedule (days)      0
# Schedule (time)    167
# Total Seasons        0
# Total Episodes       0
# Character Names    157
# Person Names       157
# Official Site      750
# dtype: int64

# %%
data.describe()
# Out:
#        Average Runtime       Rating  Total Seasons  Total Episodes
# count      1532.000000  1255.000000    1533.000000     1533.000000
# mean         51.501305     7.391554       5.537508      120.156556
# std          19.277664     0.838198       6.769474      362.353547
# min           2.000000     3.000000       1.000000        0.000000
# 25%          30.000000     7.000000       1.000000       13.000000
# 50%          60.000000     7.600000       3.000000       40.000000
# 75%          60.000000     7.900000       7.000000      110.000000
# max         190.000000     9.200000      63.000000     6850.000000

# %%
data.isnull()
data.isnull().sum()
# Out:
# Name                 0
# Summary              0
# Average Runtime      1
# End Date             1
# Premiere Date      156
# Genres               0
# Type                 0
# Language             0
# Network             69
# Rating             278
# Schedule (days)      0
# Schedule (time)    167
# Total Seasons        0
# Total Episodes       0
# Character Names    157
# Person Names       157
# Official Site      750
# dtype: int64

# %%
new_data = data.dropna()

# %%
new_data.isnull().sum()
# Out:
# Name               0
# Summary            0
# Average Runtime    0
# End Date           0
# Premiere Date      0
# Genres             0
# Type               0
# Language           0
# Network            0
# Rating             0
# Schedule (days)    0
# Schedule (time)    0
# Total Seasons      0
# Total Episodes     0
# Character Names    0
# Person Names       0
# Official Site      0
# dtype: int64

# %%
data["Official Site"].isnull().sum()
# Out:
# 750

# %%
data["Character Names"].isnull().sum()
# Out:
# 157

# %%
data["Character Names"].dropna()
# Out:
# 0       0-Walter White, 1-Jesse Pinkman, 2-Skyler Whit...
# 1       0-Captain Malcolm "Mal" Reynolds, 1-Zoe Alleyn...
# 2       0-Aang, 1-Katara, 2-Sokka, 3-Zuko, 4-Appa, 5-M...
# 3                    0-Sherlock Holmes, 1-Dr. John Watson
# 4        0-Mikasa Ackerman, 1-Armin Arlert, 2-Eren Jaeger
#                               ...
# 1522                                      0-Michelle Ward
# 1528    0-Host, 1-Mentor, 2-Mentor, 3-Mentor, 4-Mentor...
# 1530    0-Ester Steinberg, 1-Scout Durwood, 2-Jess Var...
# 1531                                               0-Host
# 1532                        0-Harriet Smith, 1-John Stone
# Name: Character Names, Length: 1376, dtype: object

# %%
data.isnull().sum()
# Out:
# Name                 0
# Summary              0
# Average Runtime      1
# End Date             1
# Premiere Date      156
# Genres               0
# Type                 0
# Language             0
# Network             69
# Rating             278
# Schedule (days)      0
# Schedule (time)    167
# Total Seasons        0
# Total Episodes       0
# Character Names    157
# Person Names       157
# Official Site      750
# dtype: int64

# %%
data.head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                              Summary  Average Runtime  \
# 0  Breaking Bad follows protagonist Walter White,...             60.0
# 1  Five hundred years in the future, a renegade c...             64.0
# 2  Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3  Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4  Known in Japan as Shingeki no Kyojin, many yea...             26.0
#
#      End Date Premiere Date                                       Genres  \
# 0  2008-01-20    2019-10-11               ['Drama', 'Crime', 'Thriller']
# 1  2002-09-20    2002-12-20    ['Drama', 'Adventure', 'Science-Fiction']
# 2  2005-02-21    2008-07-19           ['Action', 'Adventure', 'Fantasy']
# ...

# %% [markdown]
# # find the avarage of rating in rating column

# %%
new_data["Rating"].mean()
# Out:
# 7.561814345991562

# %%
c = 0
for i in new_data["Rating"]:
    c+=i
print(c)
print(c/len(new_data["Rating"]))
# Out:
# 3584.2999999999993
# 7.56181434599156

# %% [markdown]
# # how many shows are having 10 out of 10 rating

# %%
s = 0
for i in new_data["Rating"]:
    if (i == 10):
        s+=i
print(s,"shows are having 10 out of 10 ratings")
# Out:
# 0 shows are having 10 out of 10 ratings

# %% [markdown]
# # how many shows are having 8.9 ratings

# %%
s = 0
for i in new_data["Rating"]:
    if (i == 8.0):
        s+=1
print(s,"shows are having 8.9 ratings")
# Out:
# 65 shows are having 8.9 ratings

# %% [markdown]
# # how many showas are having 5.0 to 8.9 ratings

# %%
s = 0
for i in new_data["Rating"]:
    if (i >=5.0 and i <= 8.9):
        s+=1
print(s,"shows are having rating 5,0 to 8.9 ratings ")
# Out:
# 466 shows are having rating 5,0 to 8.9 ratings

# %% [markdown]
# # how many shows are having 8.0 to 10 ratings

# %%
s = 0
for i in new_data["Rating"]:
    if (i >= 8.0 and i<= 10):
        s+=1
print(s,"shows are having 8.0 to 10 ratings")
# Out:
# 156 shows are having 8.0 to 10 ratings
